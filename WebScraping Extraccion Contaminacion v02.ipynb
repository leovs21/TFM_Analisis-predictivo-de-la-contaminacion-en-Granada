# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

#Granada Norte
#Palacio de Congresos
#Ciudad deportiva

df_tablaGN = pd.DataFrame()
df_tablaPC = pd.DataFrame()
df_tablaCD = pd.DataFrame()

# %%
anio = '17'

# %%
#Enero
mes_let = 'ene'
mes_num = '01'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Febrero
mes_let = 'feb'
mes_num = '02'
for i in range(1,30) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Marzo
mes_let = 'mar'
mes_num = '03'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Abril
mes_let = 'abr'
mes_num = '04'
for i in range(1,31) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Mayo
mes_let = 'may'
mes_num = '05'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Junio
mes_let = 'jun'
mes_num = '06'
for i in range(1,31) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Julio
mes_let = 'jul'
mes_num = '07'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Agosto
mes_let = 'ago'
mes_num = '08'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Septiembre
mes_let = 'sep'
mes_num = '09'
for i in range(1,31) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Octubre
mes_let = 'oct'
mes_num = '10'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Noviembre
mes_let = 'nov'
mes_num = '11'
for i in range(1,31) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
#Diciembre
mes_let = 'dic'
mes_num = '12'
for i in range(1,32) :
    if i <= 9:
        ind = '0'+str(i)
    elif i > 9:
        ind = str(i)
    req = requests.get('http://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/'+mes_let+''+anio+'/ngr'+anio+''+mes_num+''+ind+'.htm')
    soup = BeautifulSoup(req.text, "lxml")
    My_tables = soup.find_all('table')
    if len(My_tables) == 0:
        continue
    datosT1 = My_tables[4].find_all('td')
    tabla1 = []
    for datoT1 in datosT1:
        tabla1.append(datoT1.string)

    df_tabla = pd.DataFrame()
    df_tabla[tabla1[0]] = tabla1[6:len(tabla1)-1:6]
    df_tabla[tabla1[1]] = pd.to_numeric(tabla1[7:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[2]] = pd.to_numeric(tabla1[8:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[3]] = pd.to_numeric(tabla1[9:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[4]] = pd.to_numeric(tabla1[10:len(tabla1):6], errors='coerce')
    df_tabla[tabla1[5]] = pd.to_numeric(tabla1[11:len(tabla1):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla) > 0 :
        df_tabla_resumen = pd.DataFrame()
        df_tabla_resumen['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen['SO2_Media'] = [df_tabla[tabla1[1]].mean(skipna=True)]
        df_tabla_resumen['SO2_Mediana'] = [df_tabla[tabla1[1]].median(skipna = True)]
        df_tabla_resumen['SO2_Max'] = [df_tabla[tabla1[1]].max(skipna = True)]
        df_tabla_resumen['SO2_Min'] = [df_tabla[tabla1[1]].min(skipna = True)]
        df_tabla_resumen['PART_Media'] = [df_tabla[tabla1[2]].mean(skipna=True)]
        df_tabla_resumen['PART_Mediana'] = [df_tabla[tabla1[2]].median(skipna = True)]
        df_tabla_resumen['PART_Max'] = [df_tabla[tabla1[2]].max(skipna = True)]
        df_tabla_resumen['PART_Min'] = [df_tabla[tabla1[2]].min(skipna = True)]
        df_tabla_resumen['NO2_Media'] = [df_tabla[tabla1[3]].mean(skipna=True)]
        df_tabla_resumen['NO2_Mediana'] = [df_tabla[tabla1[3]].median(skipna = True)]
        df_tabla_resumen['NO2_Max'] = [df_tabla[tabla1[3]].max(skipna = True)]
        df_tabla_resumen['NO2_Min'] = [df_tabla[tabla1[3]].min(skipna = True)]
        df_tabla_resumen['CO_Media'] = [df_tabla[tabla1[4]].mean(skipna=True)]
        df_tabla_resumen['CO_Mediana'] = [df_tabla[tabla1[4]].median(skipna = True)]
        df_tabla_resumen['CO_Max'] = [df_tabla[tabla1[4]].max(skipna = True)]
        df_tabla_resumen['CO_Min'] = [df_tabla[tabla1[4]].min(skipna = True)]
        df_tabla_resumen['O3_Media'] = [df_tabla[tabla1[5]].mean(skipna=True)]
        df_tabla_resumen['O3_Mediana'] = [df_tabla[tabla1[5]].median(skipna = True)]
        df_tabla_resumen['O3_Max'] = [df_tabla[tabla1[5]].max(skipna = True)]
        df_tabla_resumen['O3_Min'] = [df_tabla[tabla1[5]].min(skipna = True)]
        df_tablaGN = pd.concat([df_tablaGN, df_tabla_resumen])
    
    #############################
    
    datosT2 = My_tables[6].find_all('td')
    tabla2 = []
    for datoT2 in datosT2:
        tabla2.append(datoT2.string)

    df_tabla2 = pd.DataFrame()
    df_tabla2[tabla2[0]] = tabla2[6:len(tabla2)-1:6]
    df_tabla2[tabla2[1]] = pd.to_numeric(tabla2[7:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[2]] = pd.to_numeric(tabla2[8:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[3]] = pd.to_numeric(tabla2[9:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[4]] = pd.to_numeric(tabla2[10:len(tabla2):6], errors='coerce')
    df_tabla2[tabla2[5]] = pd.to_numeric(tabla2[11:len(tabla2):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla2) > 0 :
        df_tabla_resumen2 = pd.DataFrame()
        df_tabla_resumen2['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen2['SO2_Media'] = [df_tabla2[tabla2[1]].mean(skipna=True)]
        df_tabla_resumen2['SO2_Mediana'] = [df_tabla2[tabla2[1]].median(skipna = True)]
        df_tabla_resumen2['SO2_Max'] = [df_tabla2[tabla2[1]].max(skipna = True)]
        df_tabla_resumen2['SO2_Min'] = [df_tabla2[tabla2[1]].min(skipna = True)]
        df_tabla_resumen2['PART_Media'] = [df_tabla2[tabla2[2]].mean(skipna=True)]
        df_tabla_resumen2['PART_Mediana'] = [df_tabla2[tabla2[2]].median(skipna = True)]
        df_tabla_resumen2['PART_Max'] = [df_tabla2[tabla2[2]].max(skipna = True)]
        df_tabla_resumen2['PART_Min'] = [df_tabla2[tabla2[2]].min(skipna = True)]
        df_tabla_resumen2['NO2_Media'] = [df_tabla2[tabla2[3]].mean(skipna=True)]
        df_tabla_resumen2['NO2_Mediana'] = [df_tabla2[tabla2[3]].median(skipna = True)]
        df_tabla_resumen2['NO2_Max'] = [df_tabla2[tabla2[3]].max(skipna = True)]
        df_tabla_resumen2['NO2_Min'] = [df_tabla2[tabla2[3]].min(skipna = True)]
        df_tabla_resumen2['CO_Media'] = [df_tabla2[tabla2[4]].mean(skipna=True)]
        df_tabla_resumen2['CO_Mediana'] = [df_tabla2[tabla2[4]].median(skipna = True)]
        df_tabla_resumen2['CO_Max'] = [df_tabla2[tabla2[4]].max(skipna = True)]
        df_tabla_resumen2['CO_Min'] = [df_tabla2[tabla2[4]].min(skipna = True)]
        df_tabla_resumen2['O3_Media'] = [df_tabla2[tabla2[5]].mean(skipna=True)]
        df_tabla_resumen2['O3_Mediana'] = [df_tabla2[tabla2[5]].median(skipna = True)]
        df_tabla_resumen2['O3_Max'] = [df_tabla2[tabla2[5]].max(skipna = True)]
        df_tabla_resumen2['O3_Min'] = [df_tabla2[tabla2[5]].min(skipna = True)]
        df_tablaPC = pd.concat([df_tablaPC, df_tabla_resumen2])
    
    ##############################
    
    datosT3 = My_tables[8].find_all('td')
    tabla3 = []
    for datoT3 in datosT3:
        tabla3.append(datoT3.string)

    df_tabla3 = pd.DataFrame()
    df_tabla3[tabla3[0]] = tabla3[6:len(tabla3)-1:6]
    df_tabla3[tabla3[1]] = pd.to_numeric(tabla3[7:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[2]] = pd.to_numeric(tabla3[8:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[3]] = pd.to_numeric(tabla3[9:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[4]] = pd.to_numeric(tabla3[10:len(tabla3):6], errors='coerce')
    df_tabla3[tabla3[5]] = pd.to_numeric(tabla3[11:len(tabla3):6], errors='coerce')
    
    #df_tabla1.append(df_tabla)
    if len(df_tabla3) > 0 :
        df_tabla_resumen3 = pd.DataFrame()
        df_tabla_resumen3['fecha'] = ['20' + anio +'-'+ mes_num +'-'+ ind]
        df_tabla_resumen3['SO2_Media'] = [df_tabla3[tabla3[1]].mean(skipna=True)]
        df_tabla_resumen3['SO2_Mediana'] = [df_tabla3[tabla3[1]].median(skipna = True)]
        df_tabla_resumen3['SO2_Max'] = [df_tabla3[tabla3[1]].max(skipna = True)]
        df_tabla_resumen3['SO2_Min'] = [df_tabla3[tabla3[1]].min(skipna = True)]
        df_tabla_resumen3['PART_Media'] = [df_tabla3[tabla3[2]].mean(skipna=True)]
        df_tabla_resumen3['PART_Mediana'] = [df_tabla3[tabla3[2]].median(skipna = True)]
        df_tabla_resumen3['PART_Max'] = [df_tabla3[tabla3[2]].max(skipna = True)]
        df_tabla_resumen3['PART_Min'] = [df_tabla3[tabla3[2]].min(skipna = True)]
        df_tabla_resumen3['NO2_Media'] = [df_tabla3[tabla3[3]].mean(skipna=True)]
        df_tabla_resumen3['NO2_Mediana'] = [df_tabla3[tabla3[3]].median(skipna = True)]
        df_tabla_resumen3['NO2_Max'] = [df_tabla3[tabla3[3]].max(skipna = True)]
        df_tabla_resumen3['NO2_Min'] = [df_tabla3[tabla3[3]].min(skipna = True)]
        df_tabla_resumen3['CO_Media'] = [df_tabla3[tabla3[4]].mean(skipna=True)]
        df_tabla_resumen3['CO_Mediana'] = [df_tabla3[tabla3[4]].median(skipna = True)]
        df_tabla_resumen3['CO_Max'] = [df_tabla3[tabla3[4]].max(skipna = True)]
        df_tabla_resumen3['CO_Min'] = [df_tabla3[tabla3[4]].min(skipna = True)]
        df_tabla_resumen3['O3_Media'] = [df_tabla3[tabla3[5]].mean(skipna=True)]
        df_tabla_resumen3['O3_Mediana'] = [df_tabla3[tabla3[5]].median(skipna = True)]
        df_tabla_resumen3['O3_Max'] = [df_tabla3[tabla3[5]].max(skipna = True)]
        df_tabla_resumen3['O3_Min'] = [df_tabla3[tabla3[5]].min(skipna = True)]
        df_tablaCD = pd.concat([df_tablaCD, df_tabla_resumen3])

# %%
# Escribe el __DataFrame__ a CSV
df_tablaGN.to_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_GN_20'+anio+'01-12.csv', index=False)
df_tablaPC.to_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_PC_20'+anio+'01-12.csv', index=False)
df_tablaCD.to_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_CD_20'+anio+'01-12.csv', index=False)

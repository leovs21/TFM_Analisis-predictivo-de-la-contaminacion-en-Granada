# %%
import pandas as pd
from sklearn.impute import SimpleImputer #Reemplazo de datos faltantes
import numpy as np

df_tablaGN = pd.DataFrame()
df_tablaPC = pd.DataFrame()
df_tablaCD = pd.DataFrame()

# %%
#Lectura y agrupamiento de ficheros con la informacion de las distintas estaciones de medicion de la contaminacion en 
# los distintos años
for anio in range(17,20) :
    df_GN = pd.read_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_GN_20'+str(anio)+'01-12.csv')
    df_tablaGN = pd.concat([df_tablaGN, df_GN]) 
    
    df_PC = pd.read_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_PC_20'+str(anio)+'01-12.csv')
    df_tablaPC = pd.concat([df_tablaPC, df_PC])
    
    df_CD = pd.read_csv('D:/lvs/Master/ProyectoTFM/datos/contaminacion_CD_20'+str(anio)+'01-12.csv')
    df_tablaCD = pd.concat([df_tablaCD, df_CD])

with open('D:\lvs\Master\ProyectoTFM\datos\metereologicos_GranadaAeropuerto_2017-2019.json', encoding='utf-8-sig') as f_input:
    df_metGA = pd.read_json(f_input)

with open('D:\lvs\Master\ProyectoTFM\datos\metereologicos_GranadaBaseAerea_2017-2019.json', encoding='utf-8-sig') as f_input:
    df_metGBA = pd.read_json(f_input)

# %%
# Sustitucion de la media de la precipitacion en los valores ip
df_metGA['prec'] = [str(x).replace('Ip', '0.05') for x in df_metGA['prec']]
df_metGBA['prec'] = [str(x).replace('Ip', '0.05') for x in df_metGBA['prec']]

# %%
#Reemplazar ',' por '.' en los decimales y convertir los campos modificados a float
df_metGA['velmedia'] = [str(x).replace(',', '.') for x in df_metGA['velmedia']]
df_metGA['prec'] = [str(x).replace(',', '.') for x in df_metGA['prec']]
df_metGA['presMax'] = [str(x).replace(',', '.') for x in df_metGA['presMax']]
df_metGA['presMin'] = [str(x).replace(',', '.') for x in df_metGA['presMin']]
df_metGA['racha'] = [str(x).replace(',', '.') for x in df_metGA['racha']]
df_metGA['sol'] = [str(x).replace(',', '.') for x in df_metGA['sol']]
df_metGA['tmax'] = [str(x).replace(',', '.') for x in df_metGA['tmax']]
df_metGA['tmed'] = [str(x).replace(',', '.') for x in df_metGA['tmed']]
df_metGA['tmin'] = [str(x).replace(',', '.') for x in df_metGA['tmin']]

df_metGBA['velmedia'] = [str(x).replace(',', '.') for x in df_metGBA['velmedia']]
df_metGBA['prec'] = [str(x).replace(',', '.') for x in df_metGBA['prec']]
df_metGBA['presMax'] = [str(x).replace(',', '.') for x in df_metGBA['presMax']]
df_metGBA['presMin'] = [str(x).replace(',', '.') for x in df_metGBA['presMin']]
df_metGBA['racha'] = [str(x).replace(',', '.') for x in df_metGBA['racha']]
df_metGBA['sol'] = [str(x).replace(',', '.') for x in df_metGBA['sol']]
df_metGBA['tmax'] = [str(x).replace(',', '.') for x in df_metGBA['tmax']]
df_metGBA['tmed'] = [str(x).replace(',', '.') for x in df_metGBA['tmed']]
df_metGBA['tmin'] = [str(x).replace(',', '.') for x in df_metGBA['tmin']]

df_metGA['velmedia'] = df_metGA['velmedia'].astype(float)
df_metGA['prec'] = df_metGA['prec'].astype(float)
df_metGA['presMax'] = df_metGA['presMax'].astype(float)
df_metGA['presMin'] = df_metGA['presMin'].astype(float)
df_metGA['racha'] = df_metGA['racha'].astype(float)
df_metGA['sol'] = df_metGA['sol'].astype(float)
df_metGA['tmax'] = df_metGA['tmax'].astype(float)
df_metGA['tmed'] = df_metGA['tmed'].astype(float)
df_metGA['tmin'] = df_metGA['tmin'].astype(float)

df_metGBA['velmedia'] = df_metGBA['velmedia'].astype(float)
df_metGBA['prec'] = df_metGBA['prec'].astype(float)
df_metGBA['presMax'] = df_metGBA['presMax'].astype(float)
df_metGBA['presMin'] = df_metGBA['presMin'].astype(float)
df_metGBA['racha'] = df_metGBA['racha'].astype(float)
df_metGBA['sol'] = df_metGBA['sol'].astype(float)
df_metGBA['tmax'] = df_metGBA['tmax'].astype(float)
df_metGBA['tmed'] = df_metGBA['tmed'].astype(float)
df_metGBA['tmin'] = df_metGBA['tmin'].astype(float)

# %%
#Filtramos los campos que nos interesan unicamente.
df_tablaGN_fil = df_tablaGN[['fecha', 'PART_Media','PART_Mediana','PART_Max','PART_Min']]
df_tablaPC_fil = df_tablaPC[['fecha', 'PART_Media','PART_Mediana','PART_Max','PART_Min']]
df_tablaCD_fil = df_tablaCD[['fecha', 'PART_Media','PART_Mediana','PART_Max','PART_Min']]
df_metGA_fil = df_metGA[['fecha', 'dir', 'prec', 'presMax', 'presMin', 'racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia']]
df_metGBA_fil = df_metGBA[['fecha', 'dir', 'prec', 'presMax', 'presMin', 'racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia']]

# %%
#Juntamos los dataframes
df_tablaGN_metGA = pd.merge(df_tablaGN_fil, df_metGA_fil, on='fecha', how='outer').sort_values(by=['fecha'])
df_tablaGN_metGBA = pd.merge(df_tablaGN_fil, df_metGBA_fil, on='fecha', how='outer').sort_values(by=['fecha'])

df_tablaPC_metGA = pd.merge(df_tablaPC_fil, df_metGA_fil, on='fecha', how='outer').sort_values(by=['fecha'])
df_tablaPC_metGBA = pd.merge(df_tablaPC_fil, df_metGBA_fil, on='fecha', how='outer').sort_values(by=['fecha'])

df_tablaCD_metGA = pd.merge(df_tablaCD_fil, df_metGA_fil, on='fecha', how='outer').sort_values(by=['fecha'])
df_tablaCD_metGBA = pd.merge(df_tablaCD_fil, df_metGBA_fil, on='fecha', how='outer').sort_values(by=['fecha'])

# %%
#Agregamos la columna resultado como parametro a predecir la contaminacion del siguiente dia
df_tablaGN_metGA['resultado'] = np.append(df_tablaGN_metGA.iloc[1:,1].values,['nan'])
df_tablaGN_metGA['resultado'] = df_tablaGN_metGA['resultado'].astype(float)
df_tablaGN_metGBA['resultado'] = np.append(df_tablaGN_metGBA.iloc[1:,1].values,['nan'])
df_tablaGN_metGBA['resultado'] = df_tablaGN_metGBA['resultado'].astype(float)

df_tablaPC_metGA['resultado'] = np.append(df_tablaPC_metGA.iloc[1:,1].values,['nan'])
df_tablaPC_metGA['resultado'] = df_tablaPC_metGA['resultado'].astype(float)
df_tablaPC_metGBA['resultado'] = np.append(df_tablaPC_metGBA.iloc[1:,1].values,['nan'])
df_tablaPC_metGBA['resultado'] = df_tablaPC_metGBA['resultado'].astype(float)

df_tablaCD_metGA['resultado'] = np.append(df_tablaCD_metGA.iloc[1:,1].values,['nan'])
df_tablaCD_metGA['resultado'] = df_tablaCD_metGA['resultado'].astype(float)
df_tablaCD_metGBA['resultado'] = np.append(df_tablaCD_metGBA.iloc[1:,1].values,['nan'])
df_tablaCD_metGBA['resultado'] = df_tablaCD_metGBA['resultado'].astype(float)

# %%
# Corregimos datos faltantes.
df_tablaGN_metGA = df_tablaGN_metGA.reset_index()
si_tablaGN_metGA  = SimpleImputer()
si_tablaGN_metGA.fit(df_tablaGN_metGA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])
df_tablaGN_metGBA = df_tablaGN_metGBA.reset_index()
si_tablaGN_metGBA  = SimpleImputer()
si_tablaGN_metGBA.fit(df_tablaGN_metGBA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])

df_tablaPC_metGA = df_tablaPC_metGA.reset_index()
si_tablaPC_metGA  = SimpleImputer()
si_tablaPC_metGA.fit(df_tablaPC_metGA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])
df_tablaPC_metGBA = df_tablaPC_metGBA.reset_index()
si_tablaPC_metGBA  = SimpleImputer()
si_tablaPC_metGBA.fit(df_tablaPC_metGBA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])

df_tablaCD_metGA = df_tablaCD_metGA.reset_index()
si_tablaCD_metGA  = SimpleImputer()
si_tablaCD_metGA.fit(df_tablaCD_metGA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])
df_tablaCD_metGBA = df_tablaCD_metGBA.reset_index()
si_tablaCD_metGBA  = SimpleImputer()
si_tablaCD_metGBA.fit(df_tablaCD_metGBA[['PART_Media','PART_Mediana','PART_Max','PART_Min','dir','prec','presMax','presMin','racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'resultado']])
# Out:
# SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)

# %%
# Reemplazo datos faltantes en los datafram de Granada-Norte
df_tablaGN_metGA["PART_Media"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["PART_Media"].values.reshape(-1, 1))
df_tablaGN_metGA["PART_Mediana"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["PART_Mediana"].values.reshape(-1, 1))
df_tablaGN_metGA["PART_Max"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["PART_Max"].values.reshape(-1, 1))
df_tablaGN_metGA["PART_Min"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["PART_Min"].values.reshape(-1, 1))
df_tablaGN_metGA["dir"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["dir"].values.reshape(-1, 1))
df_tablaGN_metGA["prec"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["prec"].values.reshape(-1, 1))
df_tablaGN_metGA["presMax"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["presMax"].values.reshape(-1, 1))
df_tablaGN_metGA["presMin"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["presMin"].values.reshape(-1, 1))
df_tablaGN_metGA["racha"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["racha"].values.reshape(-1, 1))
df_tablaGN_metGA["sol"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["sol"].values.reshape(-1, 1))
df_tablaGN_metGA["tmed"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["tmed"].values.reshape(-1, 1))
df_tablaGN_metGA["tmax"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["tmax"].values.reshape(-1, 1))
df_tablaGN_metGA["tmin"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["tmin"].values.reshape(-1, 1))
df_tablaGN_metGA["velmedia"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["velmedia"].values.reshape(-1, 1))
df_tablaGN_metGA["resultado"] = si_tablaGN_metGA.fit_transform(df_tablaGN_metGA["resultado"].values.reshape(-1, 1))

df_tablaGN_metGBA["PART_Media"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["PART_Media"].values.reshape(-1, 1))
df_tablaGN_metGBA["PART_Mediana"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["PART_Mediana"].values.reshape(-1, 1))
df_tablaGN_metGBA["PART_Max"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["PART_Max"].values.reshape(-1, 1))
df_tablaGN_metGBA["PART_Min"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["PART_Min"].values.reshape(-1, 1))
df_tablaGN_metGBA["dir"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["dir"].values.reshape(-1, 1))
df_tablaGN_metGBA["prec"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["prec"].values.reshape(-1, 1))
df_tablaGN_metGBA["presMax"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["presMax"].values.reshape(-1, 1))
df_tablaGN_metGBA["presMin"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["presMin"].values.reshape(-1, 1))
df_tablaGN_metGBA["racha"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["racha"].values.reshape(-1, 1))
df_tablaGN_metGBA["sol"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["sol"].values.reshape(-1, 1))
df_tablaGN_metGBA["tmed"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["tmed"].values.reshape(-1, 1))
df_tablaGN_metGBA["tmax"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["tmax"].values.reshape(-1, 1))
df_tablaGN_metGBA["tmin"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["tmin"].values.reshape(-1, 1))
df_tablaGN_metGBA["velmedia"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["velmedia"].values.reshape(-1, 1))
df_tablaGN_metGBA["resultado"] = si_tablaGN_metGBA.fit_transform(df_tablaGN_metGBA["resultado"].values.reshape(-1, 1))

# %%
# Reemplazo datos faltantes en los datafram del palacio de los congresos
df_tablaPC_metGA["PART_Media"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["PART_Media"].values.reshape(-1, 1))
df_tablaPC_metGA["PART_Mediana"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["PART_Mediana"].values.reshape(-1, 1))
df_tablaPC_metGA["PART_Max"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["PART_Max"].values.reshape(-1, 1))
df_tablaPC_metGA["PART_Min"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["PART_Min"].values.reshape(-1, 1))
df_tablaPC_metGA["dir"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["dir"].values.reshape(-1, 1))
df_tablaPC_metGA["prec"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["prec"].values.reshape(-1, 1))
df_tablaPC_metGA["presMax"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["presMax"].values.reshape(-1, 1))
df_tablaPC_metGA["presMin"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["presMin"].values.reshape(-1, 1))
df_tablaPC_metGA["racha"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["racha"].values.reshape(-1, 1))
df_tablaPC_metGA["sol"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["sol"].values.reshape(-1, 1))
df_tablaPC_metGA["tmed"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["tmed"].values.reshape(-1, 1))
df_tablaPC_metGA["tmax"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["tmax"].values.reshape(-1, 1))
df_tablaPC_metGA["tmin"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["tmin"].values.reshape(-1, 1))
df_tablaPC_metGA["velmedia"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["velmedia"].values.reshape(-1, 1))
df_tablaPC_metGA["resultado"] = si_tablaPC_metGA.fit_transform(df_tablaPC_metGA["resultado"].values.reshape(-1, 1))

df_tablaPC_metGBA["PART_Media"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["PART_Media"].values.reshape(-1, 1))
df_tablaPC_metGBA["PART_Mediana"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["PART_Mediana"].values.reshape(-1, 1))
df_tablaPC_metGBA["PART_Max"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["PART_Max"].values.reshape(-1, 1))
df_tablaPC_metGBA["PART_Min"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["PART_Min"].values.reshape(-1, 1))
df_tablaPC_metGBA["dir"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["dir"].values.reshape(-1, 1))
df_tablaPC_metGBA["prec"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["prec"].values.reshape(-1, 1))
df_tablaPC_metGBA["presMax"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["presMax"].values.reshape(-1, 1))
df_tablaPC_metGBA["presMin"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["presMin"].values.reshape(-1, 1))
df_tablaPC_metGBA["racha"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["racha"].values.reshape(-1, 1))
df_tablaPC_metGBA["sol"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["sol"].values.reshape(-1, 1))
df_tablaPC_metGBA["tmed"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["tmed"].values.reshape(-1, 1))
df_tablaPC_metGBA["tmax"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["tmax"].values.reshape(-1, 1))
df_tablaPC_metGBA["tmin"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["tmin"].values.reshape(-1, 1))
df_tablaPC_metGBA["velmedia"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["velmedia"].values.reshape(-1, 1))
df_tablaPC_metGBA["resultado"] = si_tablaPC_metGBA.fit_transform(df_tablaPC_metGBA["resultado"].values.reshape(-1, 1))

# %%
# Reemplazo datos faltantes en los datafram de Armilla
df_tablaCD_metGA["PART_Media"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["PART_Media"].values.reshape(-1, 1))
df_tablaCD_metGA["PART_Mediana"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["PART_Mediana"].values.reshape(-1, 1))
df_tablaCD_metGA["PART_Max"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["PART_Max"].values.reshape(-1, 1))
df_tablaCD_metGA["PART_Min"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["PART_Min"].values.reshape(-1, 1))
df_tablaCD_metGA["dir"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["dir"].values.reshape(-1, 1))
df_tablaCD_metGA["prec"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["prec"].values.reshape(-1, 1))
df_tablaCD_metGA["presMax"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["presMax"].values.reshape(-1, 1))
df_tablaCD_metGA["presMin"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["presMin"].values.reshape(-1, 1))
df_tablaCD_metGA["racha"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["racha"].values.reshape(-1, 1))
df_tablaCD_metGA["sol"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["sol"].values.reshape(-1, 1))
df_tablaCD_metGA["tmed"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["tmed"].values.reshape(-1, 1))
df_tablaCD_metGA["tmax"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["tmax"].values.reshape(-1, 1))
df_tablaCD_metGA["tmin"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["tmin"].values.reshape(-1, 1))
df_tablaCD_metGA["velmedia"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["velmedia"].values.reshape(-1, 1))
df_tablaCD_metGA["resultado"] = si_tablaCD_metGA.fit_transform(df_tablaCD_metGA["resultado"].values.reshape(-1, 1))

df_tablaCD_metGBA["PART_Media"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["PART_Media"].values.reshape(-1, 1))
df_tablaCD_metGBA["PART_Mediana"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["PART_Mediana"].values.reshape(-1, 1))
df_tablaCD_metGBA["PART_Max"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["PART_Max"].values.reshape(-1, 1))
df_tablaCD_metGBA["PART_Min"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["PART_Min"].values.reshape(-1, 1))
df_tablaCD_metGBA["dir"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["dir"].values.reshape(-1, 1))
df_tablaCD_metGBA["prec"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["prec"].values.reshape(-1, 1))
df_tablaCD_metGBA["presMax"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["presMax"].values.reshape(-1, 1))
df_tablaCD_metGBA["presMin"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["presMin"].values.reshape(-1, 1))
df_tablaCD_metGBA["racha"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["racha"].values.reshape(-1, 1))
df_tablaCD_metGBA["sol"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["sol"].values.reshape(-1, 1))
df_tablaCD_metGBA["tmed"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["tmed"].values.reshape(-1, 1))
df_tablaCD_metGBA["tmax"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["tmax"].values.reshape(-1, 1))
df_tablaCD_metGBA["tmin"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["tmin"].values.reshape(-1, 1))
df_tablaCD_metGBA["velmedia"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["velmedia"].values.reshape(-1, 1))
df_tablaCD_metGBA["resultado"] = si_tablaCD_metGBA.fit_transform(df_tablaCD_metGBA["resultado"].values.reshape(-1, 1))

# %%
#Eliminacion columna index
df_tablaGN_metGA = df_tablaGN_metGA.drop(['index'], axis=1)
df_tablaGN_metGBA = df_tablaGN_metGBA.drop(['index'], axis=1)

df_tablaPC_metGA = df_tablaPC_metGA.drop(['index'], axis=1)
df_tablaPC_metGBA = df_tablaPC_metGBA.drop(['index'], axis=1)

df_tablaCD_metGA = df_tablaCD_metGA.drop(['index'], axis=1)
df_tablaCD_metGBA = df_tablaCD_metGBA.drop(['index'], axis=1)

# %%
# Escribe el __DataFrame__ a CSV
df_tablaGN_metGA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaGN_metGA.csv', index=False)
df_tablaGN_metGBA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaGN_metGBA.csv', index=False)
df_tablaPC_metGA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaPC_metGA.csv', index=False)
df_tablaPC_metGBA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaPC_metGBA.csv', index=False)
df_tablaCD_metGA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaCD_metGA.csv', index=False)
df_tablaCD_metGBA.to_csv('D:/lvs/Master/ProyectoTFM/datos/Post-Procesing/df_tablaCD_metGBA.csv', index=False)
